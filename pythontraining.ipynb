# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanism10-beep/program-training/blob/main/pythontraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter n"))
k=int(input("enter k"))
j=int(input("enter j"))
m=int(input("enter m"))
p=int(input("enter p"))
if k<0 or j<0:
  print("invalid input")

noofmonkeys=m//k+p//j
n=n-noofmonkeys
if m%k!=0 or p%j!=0:
   n=n-1
print(n)
# Out:
# enter n20
# enter k2
# enter j3
# enter m12
# enter p12
# 10
